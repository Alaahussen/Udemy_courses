# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(4,5))

# %%
df=pd.read_csv("C:\\Users\\Pro\\Desktop\\udemy_courses.csv")
df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
df.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %% [markdown]
# how many null values?

# %%
df.isna().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 6

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
 df["is_paid"].value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %%
df.drop(columns=['url'],inplace=True)

# %%
df.shape
# Out:
# (3672, 11)

# %%
#changing the 'published_timestamp' to correct Datatye
df['published_timestamp'] = pd.to_datetime(df['published_timestamp'])
df['year'] = df['published_timestamp'].dt.year
df
# Out:
#       course_id                                       course_title  is_paid  \
# 0       1070968                 Ultimate Investment Banking Course     True
# 1       1113822  Complete GST Course & Certification - Grow You...     True
# 2       1006314  Financial Modeling for Business Analysts and C...     True
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...     True
# 4       1011058       How To Maximize Your Profits Trading Options     True
# ...         ...                                                ...      ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...     True
# 3674    1088178  How To Design A WordPress Website With No Codi...     True
# 3675     635248                      Learn and Build using Polymer     True
# 3676     905096  CSS Animations: Create Amazing Effects on Your...     True
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...     True
#
# ...

# %% [markdown]
# # what is the number of maxium reviews

# %%
df["num_reviews"].max()
# Out:
# 27445

# %%
df[df["num_reviews"]==df["num_reviews"].max()]["course_title"]
# Out:
# 3230    The Web Developer Bootcamp
# Name: course_title, dtype: object

# %%
df["subject"].value_counts()
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %%
df["course_id"].nunique()
# Out:
# 3672

# %% [markdown]
# # what is the coursename of maxium duration?

# %%
df[df["content_duration"]==df["content_duration"].max()]["course_title"]
# Out:
# 1658    The Complete Figure Drawing Course HD
# Name: course_title, dtype: object

# %%
df[df["price"]==df["price"].max()]["subject"]
# Out:
# 0       Business Finance
# 4       Business Finance
# 9       Business Finance
# 10      Business Finance
# 11      Business Finance
#               ...
# 3592     Web Development
# 3620     Web Development
# 3642     Web Development
# 3652     Web Development
# 3654     Web Development
# Name: subject, Length: 295, dtype: object

# %% [markdown]
# # How many paid subjects?

# %%
sns.countplot(df["subject"],hue=df["is_paid"],order = df.subject.value_counts().index)
# Out:
# C:\Users\Pro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='subject', ylabel='count'>

# %% [markdown]
# # what is the subject of maxium price?

# %%
sns.barplot(df["subject"],df["price"],hue=df["level"])
# Out:
# C:\Users\Pro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='subject', ylabel='price'>

# %% [markdown]
# # What is the relation between number of subscribers and paidcourses?

# %%
plt.title('Average Demand (Free/Paid)')
sns.barplot(x='is_paid', y='num_subscribers', data=df)
# Out:
# <AxesSubplot:title={'center':'Average Demand (Free/Paid)'}, xlabel='is_paid', ylabel='num_subscribers'>

# %% [markdown]
# # what is the relation of number of reviewers and paidcourses?

# %%
sns.barplot(df['subject'],df['num_reviews'],hue=df["is_paid"])
# Out:
# C:\Users\Pro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='subject', ylabel='num_reviews'>

# %% [markdown]
# # what is the subject of maxium subscribers?

# %%
sns.barplot(df['subject'],df['num_subscribers'])
# Out:
# C:\Users\Pro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='subject', ylabel='num_subscribers'>

# %%
X=df.groupby('subject').sum()['num_subscribers']
X
# Out:
# subject
# Business Finance       1868711
# Graphic Design         1063148
# Musical Instruments     846689
# Web Development        7937287
# Name: num_subscribers, dtype: int64

# %%
plt.figure(figsize=(5,6))
plt.pie(X,labels=X.index,autopct ='%1.2f%%',shadow = True, explode = [0,0,0,0.05])
plt.title('Average Demand by Course Subjects')
plt.axis('equal')
plt.show()

# %% [markdown]
# how many levels?

# %%
sns.countplot(data = df, x = 'level', hue = 'subject', order = df.level.value_counts().index)
# Out:
# <AxesSubplot:xlabel='level', ylabel='count'>

# %% [markdown]
# # howmany subjects?

# %%
plt.pie(df.subject.value_counts(), labels = ['Web Development', 'Business Finance', 'Musical Instruments', 'Graphic Design'], 
       explode = [0 ,0.2, 0 ,0], colors = ['r', 'g', 'b', 'y'], autopct = '%1.f%%')
plt.title('The perecentage of each subject')
plt.axis('equal')
plt.show()

# %% [markdown]
# # howmany paid level?

# %%
sns.countplot(df['level'],hue=df['is_paid'],order = df.level.value_counts().index)
# Out:
# C:\Users\Pro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='level', ylabel='count'>

# %% [markdown]
# # what is the relation between subject and content_duration?

# %%
plt.bar(df["subject"],df["content_duration"])
# Out:
# <BarContainer object of 3672 artists>

# %%
sns.barplot(df["subject"],df['num_lectures'],hue=df['is_paid'])
# Out:
# C:\Users\Pro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='subject', ylabel='num_lectures'>

# %%
plt.figure(figsize=(5,6))
sns.scatterplot(x='price',y='num_subscribers',data=df)
plt.show()

# %%
plt.figure(figsize=(5,6))
sns.scatterplot(x='num_lectures',y='num_subscribers',data=df)
plt.show()

# %%
plt.figure(figsize=(5,6))
sns.scatterplot(x='content_duration',y='num_subscribers',data=df)
plt.show()

# %%
sns.scatterplot(df['price'],df['num_reviews'])
# Out:
# C:\Users\Pro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price', ylabel='num_reviews'>

# %%
sns.scatterplot(df['price'],df['num_lectures'])
# Out:
# C:\Users\Pro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price', ylabel='num_lectures'>

# %%
sns.scatterplot(df['price'],df['content_duration'])
# Out:
# C:\Users\Pro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price', ylabel='content_duration'>

# %%
sns.scatterplot(df['num_reviews'],df['num_lectures'])
# Out:
# C:\Users\Pro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='num_reviews', ylabel='num_lectures'>

# %%
sns.scatterplot(df['content_duration'],df['num_reviews'])
# Out:
# C:\Users\Pro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='content_duration', ylabel='num_reviews'>

# %%
sns.jointplot(data = df , x = 'num_subscribers', y = 'price', kind = 'reg')

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
plt.pie(df["is_paid"].value_counts(),autopct="%1.2f%%",labels=[True,False])
# Out:
# ([<matplotlib.patches.Wedge at 0x250b0a84250>,
# ...
#  [Text(-1.0615378903763522, 0.28833540763375515, 'True'),
#   Text(1.061537897125329, -0.28833538278666787, 'False')],
#  [Text(-0.5790206674780102, 0.15727385870932095, '91.56%'),
#   Text(0.5790206711592704, -0.15727384515636428, '8.44%')])

# %%
sns.histplot(df['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='Count'>

# %%
sns.histplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
plt.bar(df['year'],df['num_subscribers'])
plt.show()

# %%
plt.bar(df['year'],df['num_reviews'])
plt.show()

# %%
sns.barplot(df['year'],df['price'])
# Out:
# C:\Users\Pro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
x=df.groupby('year').sum()['price']
x
# Out:
# year
# 2011      310
# 2012     1835
# 2013    10785
# 2014    23780
# 2015    67830
# 2016    84165
# 2017    54025
# Name: price, dtype: int64

# %% [markdown]
# # what is the most 5 courses that have maxium number of subscribers?

# %%
sns.catplot(data = df, kind = 'bar', height = 8, aspect = 2.4, x = df.course_title.loc[df.num_lectures.sort_values(ascending = False).head().index], y = 'num_subscribers')

# %% [markdown]
# # what is the most 5 courses that have maxium number of lectures?

# %%
sns.catplot(data = df, kind = 'bar', height = 8, aspect = 2.4, x = df.course_title.loc[df.num_lectures.sort_values(ascending = False).head().index], y = 'num_lectures')

# %% [markdown]
# # what is the most 5 courses that have longest duration?

# %%
sns.catplot(data = df, kind = 'bar', height = 8, aspect = 2.4, x = df.course_title.loc[df.content_duration.sort_values(ascending = False).head().index], y = 'content_duration')

# %% [markdown]
# # what is the most 5 courses that have maxium reviews?

# %%
sns.catplot(data = df, kind = 'bar', height = 8, aspect = 2.4, x = df.course_title.loc[df.num_reviews.sort_values(ascending = False).head().index], y = 'num_reviews')
